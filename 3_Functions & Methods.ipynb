# %% [markdown]
# ### Functions Perform Actions

# %% [markdown]
# a piece of reusable code that solves a specific task

# %%
pd.read_csv() #turns csv into a table in python
plt.plot() #turns data into a line plot
plt.show() #displays plot in a new window

# %% [markdown]
# ### Anatomy of a Function

# %% [markdown]
# #### Positional Arguments

# %% [markdown]
# - the positional arguments must be placed in a particular order

# %% [markdown]
# #### Inputs

# %% [markdown]
# - tell the function how to operate (ie. do it's job)

# %% [markdown]
# #### Key Word Arguments

# %% [markdown]
# - come after the positional arguments
# - and they can come in any order

# %% [markdown]
# ### Built-In Functions

# %%
max()
#pass a list through it and it will select the highest number

# %%
round(input1, input2)
#first input is the item you want to round
#second input is what you round it to
#not taking in the second input it just rounds to a whole number

# %% [markdown]
# The square brackets in the documentation allows for either version to be called
# ![image.png](attachment:image.png)

# %% [markdown]
# making "ndigits" an optional argument

# %%
len()

# %% [markdown]
# ### Methods

# %% [markdown]
# functions that belong to objects
# - called with the dot.(notation)
#
# variable.method()

# %%
df.index("column")
#index of the column

# %%
df.count("item")
#counts the occurance of an item

# %%
variable.capitalize()
#capitalizing the variable that stands for string with first letter is capitalized

# %%
variable.replace("Z", "sa")
#z is replaced with sa

# %% [markdown]
# Everything in python is an object.
# - and objects have methods associated to them based on the type they are
#
# This is why sometimes an Attribute Error comes up.

# %% [markdown]
# ### Methods can Change the Objects they're called on

# %%
df.append("string") #extends with string
